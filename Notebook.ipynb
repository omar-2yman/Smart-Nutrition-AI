# %%
# !pip install roboflow ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 80.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 113.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lycNFs64zkVd5G6o9Ngs")
project = rf.workspace("ahmad-nabil").project("food-calories-rvvbo")
version = project.version(3)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to FOOD-CALORIES--3 in yolov8:: 100%|██████████| 6610/6610 [00:01<00:00, 6588.61it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/content/FOOD-CALORIES--3/data.yaml",
    epochs=30,
    imgsz=640
)
# Out:
# ...
# Ultralytics 8.4.48 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from IPython.display import Image

Image('/content/runs/detect/train/results.png')

# %%
Image('/content/runs/detect/train/confusion_matrix.png')

# %%
# !ls /content/runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
from ultralytics import YOLO

model = YOLO('/content/runs/detect/train/weights/best.pt')

results = model.predict(
    source='/content/FOOD-CALORIES--3/test/images/0a8b7d119116af1c_jpg.rf.47eae0fb0e10c4dc1919889a4f8e7de1.jpg',
    save=True,
    conf=0.25
)
# Out:
# image 1/1 /content/FOOD-CALORIES--3/test/images/0a8b7d119116af1c_jpg.rf.47eae0fb0e10c4dc1919889a4f8e7de1.jpg: 640x640 1 hamburger - 341, 8.9ms
# Speed: 2.0ms preprocess, 8.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/YOLO-V8-CAM/runs/detect/predict-7

# %%
from IPython.display import Image

Image('/content/YOLO-V8-CAM/runs/detect/predict-7/0a8b7d119116af1c_jpg.rf.47eae0fb0e10c4dc1919889a4f8e7de1.jpg')

# %%
# !pip install grad-cam
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 58.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for grad-cam: filename=grad_cam-1.5.5-py3-none-any.whl size=44286 sha256=8f541d64542636132f8935aa8b2af8820ee87d0056e1385fdef39f7426bb05e9
#   Stored in directory: /root/.cache/pip/wheels/fb/3b/09/2afc520f3d69bc26ae6bd87416759c820a3f7d05c1a077bbf6
# Successfully built grad-cam
# ...

# %%
# !git clone https://github.com/rigvedrs/YOLO-V8-CAM.git
# Out:
# Cloning into 'YOLO-V8-CAM'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 175 (delta 39), reused 22 (delta 22), pack-reused 123 (from 1)
# Receiving objects: 100% (175/175), 53.12 MiB | 26.12 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
# %cd YOLO-V8-CAM
# Out:
# /content/YOLO-V8-CAM

# %%
# !pip install ultralytics grad-cam

# %%
# !ls
# Out:
# images	     README.md	YOLO_v11_EigenCAM.ipynb
# LICENSE.txt  test	YOLO_v26_EigenCAM.ipynb
# models	     yolo_cam	YOLO_v8n_EigenCAM.ipynb

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
from yolo_cam.eigen_cam import EigenCAM
from yolo_cam.utils.image import show_cam_on_image, scale_cam_image

# %%
model = YOLO('/content/runs/detect/train/weights/best.pt')
model = model.cpu()

# %%
img = cv2.imread('/content/YOLO-V8-CAM/runs/detect/predict-7/0a8b7d119116af1c_jpg.rf.47eae0fb0e10c4dc1919889a4f8e7de1.jpg')
img = cv2.resize(img, (640, 640))
rgb_img = img.copy()
img = np.float32(img) / 255

# %%
target_layers =[model.model.model[-4]]

# %%
cam = EigenCAM(model, target_layers,task='od')
grayscale_cam = cam(rgb_img)[0, :, :]
cam_image = show_cam_on_image(img, grayscale_cam, use_rgb=True)
plt.imshow(cam_image)
plt.show()
# Out:
# 0: 640x640 1 hamburger - 341, 165.1ms
# Speed: 5.8ms preprocess, 165.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
im = cv2.cvtColor(rgb_img, cv2.COLOR_RGB2BGR)
Image.fromarray(np.hstack((im, cam_image)))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x640>
